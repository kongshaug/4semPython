# %% [markdown]
# # Ex 1 Classes
# Create 3 classes: Student, DataSheet and Course
# A student has a data_sheet and a data_sheet has multiple courses in particular order
#
# Each course has name, classroom, teacher, ETCS and optional grade if course is taken.
#
# In Student create init() so that a Student can be initiated with name, gender, data_sheet and image_url
#
# In DataSheet create a method to get_grades_as_list()
#
# In student create a method: get_avg_grade()
#
# Create a function that can generate n number of students with random: name, gender, courses (from a fixed list of course names), grades, img_url
#
#     Let the function write the result to a csv file with format stud_name, course_name, teacher, ects, classroom, grade, img_url

# %%
import random
import csv
import platform

class Course():
    def __init__(self, name, room, teacher, ETCS, grade = None):
        self.name = name
        self.room = room
        self.teacher = teacher
        self.ETCS = ETCS
        self.grade = grade
        
    def __repr__(self):
        return 'course(%r, %r)' % (self.name, self.room)
    
class Data_sheed():
    def __init__(self, courses = []):
        self.courses = courses
        
    def add_course(self):
        self.course.append(course)
    def get_grade_as_list(self):
        grades = []
        for cours in self.courses:
            grades.append(cours.grade)
        return grades
    
            
        #Make a method on Student class that can show progression of the study in % 
        #(add up ECTS from all passed courses divided by total of 150 total points (equivalent to 5 semesters))
class Student():
    def __init__(self, data_sheed, name, gender, image_url):
        self.data_sheed = data_sheed
        self.name = name
        self.gender = gender
        self.image_url = image_url
    
    def __str__(self):
        return '{name} how is a: {gender} with a picture {picture}.'.format(
            name=self.name, gender=self.gender, picture=self.image_url)
    
    def __repr__(self):
        return 'Student(%r, %r, %r)' % (self.name, self.gender, self.image_url[:5])
    def show_prog(self):
        sum_of_etcs = 0
        for cours in self.data_sheed.courses:
            etcs = cours.ETCS
            sum_of_etcs += etcs
        return sum_of_etcs/150
    
    def get_all_courses(self):
        return self.data_sheed.courses
    
    def get_avg_grade(self):
        grades = self.data_sheed.get_grade_as_list()
        return sum(grades)
    

course_one = Course("danish", "a12", "john",10, 2)
course_two = Course("programming", "n22", "mr robot",200,7)
course_three = Course("english", "b3", "man",5,12)

course_list = [course_one, course_two, course_three]

data_sheed_one = Data_sheed(course_list)

student = Student(data_sheed_one, "boy name", "man", "https://redtricom.files.wordpress.com/2019/07/first-day-of-school-photo-1.jpg?w=605")

def generate_rand_students(num_of_students):
    names = ["tobi", "lasse", "jim","charles","mani","malu","inger","lars","lulu", "manuel","lykke","john","magnus","elise","anders","nils","jens jacob","kim","kauline","gustav"]
    gender = ["l","g","b","t","+","s"]
    images = ["https://pbs.twimg.com/profile_images/949787136030539782/LnRrYf6e_400x400.jpg","https://www.atomix.com.au/media/2017/07/StockPhotoBanner.jpg","https://i.imgur.com/06FjyOY.jpg","https://previews.123rf.com/images/jcjgphotography/jcjgphotography1110/jcjgphotography111000052/10860554-hungry-for-a-corn-dog.jpg"]
    grades = [0,2,4,7,10,12]
    course_name=["danish","latin","spanish","python","math","surfing","botanik","dansing","cooking class","java"]
    rooms = ["a12","a11","a10","a09","a02","a01","a04","a05"]
    teachers =["man in sweather","the old guy","the new guy","the good one","the boring one"]
    ETCS = [2,5,10,15]
    students = []
    for x in range(num_of_students):
        courses = []
        for x in range(random.randint(1,5)):
            course = Course(course_name[random.randint(0,9)], 
                  rooms[random.randint(0,7)], 
                  teachers[random.randint(0,4)], 
                  ETCS[random.randint(0,3)], 
                  grades[random.randint(0,5)])
            courses.append(course)
        data_sheed = Data_sheed(courses)
        student = Student(data_sheed, names[random.randint(0,18)], random.choice(gender), random.choice(images))
        students.append(student)
    
    if platform.system() == 'Windows':
        newline=''
    else:
        newline=None
    with open('studens.csv', 'w', newline=newline) as output_file:
        output_writer = csv.writer(output_file)
        output_writer.writerow(["stud_name", "course_name", "teacher", "ects", "classroom", "grade", "img_url"])
        for student in students:
            cours = student.data_sheed.courses[0]
            output_writer.writerow([student.name, cours.name, cours.teacher, cours.ETCS, 
                                    cours.room, cours.grade, student.image_url, student.gender ])

        
    
ans = generate_rand_students(8)


#stud_name, course_name, teacher, ects, classroom, grade, img_url

# %% [markdown]
# Read student data into a list from a csv file:
#
#     loop through the list and print each student with name, img_url and avg_grade.
#     sort the list by avg_grade

# %%
import csv

file_name = "studens.csv"
with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    students = []
    for row in reader:
        name, course_name, teacher, ects, room, grade, url, gender = row
        course = Course( course_name, room, teacher, ects, int(grade))
        data_sheed = Data_sheed([course])
        students.append(Student(data_sheed, name, gender, url))
    sort_stud = sorted(students, key=Student.get_avg_grade)
    for student in sort_stud:
        
        print(student.name, student.image_url, student.get_avg_grade())
# Out:
# charles https://i.imgur.com/06FjyOY.jpg 0
# manuel https://previews.123rf.com/images/jcjgphotography/jcjgphotography1110/jcjgphotography111000052/10860554-hungry-for-a-corn-dog.jpg 0
# jens jacob https://previews.123rf.com/images/jcjgphotography/jcjgphotography1110/jcjgphotography111000052/10860554-hungry-for-a-corn-dog.jpg 0
# jens jacob https://www.atomix.com.au/media/2017/07/StockPhotoBanner.jpg 0
# jens jacob https://pbs.twimg.com/profile_images/949787136030539782/LnRrYf6e_400x400.jpg 0
# manuel https://previews.123rf.com/images/jcjgphotography/jcjgphotography1110/jcjgphotography111000052/10860554-hungry-for-a-corn-dog.jpg 4
# lulu https://pbs.twimg.com/profile_images/949787136030539782/LnRrYf6e_400x400.jpg 4
# lulu https://pbs.twimg.com/profile_images/949787136030539782/LnRrYf6e_400x400.jpg 12

# %% [markdown]
# create a bar chart with student_name on x and avg_grade on y-axis

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt



names = [stud.name for stud in sort_stud]
grades = [stud.get_avg_grade() for stud in sort_stud]

print(grades)
print(names)

plt.bar(names,grades)
# Out:
# [7, 10]
# ['lulu', 'jens jacob']
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %% [markdown]
# Make a method on Student class that can show progression of the study in % (add up ECTS from all passed courses divided by total of 150 total points (equivalent to 5 semesters))
#
# Show a line graph of distribution of study progression on x-axis and number of students in each category on y-axis. (e.g. make 10 categories from 0-100%)
# NOT DONE, forstod ikke.

# %% [markdown]
# # Ex 2 Exceptions
# Create a function that can take a list of students and return the 3 students closest to completing their study.

# %%
def generate_rand_students_for_exceptions(num_of_students):
    """the method returns the students insted of putting them in the database like the random method found above"""
    names = ["tobi", "lasse", "jim","charles","mani","malu","inger","lars","lulu", "manuel","lykke","john","magnus","elise","anders","nils","jens jacob","kim","kauline","gustav"]
    gender = ["l","g","b","t","+","s"]
    images = ["https://pbs.twimg.com/profile_images/949787136030539782/LnRrYf6e_400x400.jpg","https://www.atomix.com.au/media/2017/07/StockPhotoBanner.jpg","https://i.imgur.com/06FjyOY.jpg","https://previews.123rf.com/images/jcjgphotography/jcjgphotography1110/jcjgphotography111000052/10860554-hungry-for-a-corn-dog.jpg"]
    grades = [0,2,4,7,10,12]
    course_name=["danish","latin","spanish","python","math","surfing","botanik","dansing","cooking class","java"]
    rooms = ["a12","a11","a10","a09","a02","a01","a04","a05"]
    teachers =["man in sweather","the old guy","the new guy","the good one","the boring one"]
    ETCS = [2,5,10,15]
    students = []
    for x in range(num_of_students):
        courses = []
        for x in range(random.randint(1,15)):
            course = Course(course_name[random.randint(0,9)], 
                  rooms[random.randint(0,7)], 
                  teachers[random.randint(0,4)], 
                  ETCS[random.randint(0,3)], 
                  grades[random.randint(0,5)])
            courses.append(course)
        data_sheed = Data_sheed(courses)
        student = Student(data_sheed, names[random.randint(0,18)], random.choice(gender), random.choice(images))
        students.append(student)
    return students

# %% [markdown]
# If list is shorter than 3 raise your own custom exception (NotEnoughStudentsException)

# %%
def furthest_students(students):
    """findes the 3 students that are furthest with their studies. sorted on etcs points"""
    sort_stud = sorted(students, key=Student.show_prog)
    if(len(sort_stud)<3):
        raise NotEnoughStudentsException("you supplied: ",len(sort_stud)," but 3 is needed" )
    return sort_stud[-3:]
   

#students is a list of random students with a bunsh of courses
students = generate_rand_students_for_exceptions(4)
furthest_students(students)
print(students)
# Out:
# [Student('lulu', 'g', 'https'), Student('john', 's', 'https'), Student('lasse', 'g', 'https'), Student('lars', 't', 'https')]

# %% [markdown]
# If list is shorter than 3 raise your own custom exception (NotEnoughStudentsException)

# %%
class NotEnoughStudentsException(IndexError):
    pass

# %% [markdown]
# Create another function that can create a csv file with 3 students closest to completion
#
# If an exception is raised write an appropriate message to the file

# %%
import platform

def safe_best_students(all_students):
    try:
        if platform.system() == 'Windows':
            newline=''
        else:
            newline=None

        best_students = furthest_students(all_students)
    
    except NotEnoughStudentsException as e:
        print("the list of students was to short")
        with open('best_students.csv', 'w', newline=newline) as output_file:
            output_writer = csv.writer(output_file)
            output_writer.writerow(["Here is a very good error message telling you that you fucked up, its alright all you need to do to fix it is ........?"])
        
    else:
       
        with open('best_students.csv', 'w', newline=newline) as output_file:
            output_writer = csv.writer(output_file)
            output_writer.writerow(["stud_name", "course_name", "teacher", "ects", "classroom", "grade", "img_url"])
            for student in best_students:
                cours = student.data_sheed.courses[0]
                output_writer.writerow([student.name, cours.name, cours.teacher, cours.ETCS, 
                                        cours.room, cours.grade, student.image_url, student.gender ])
    
safe_best_students(students)

# %% [markdown]
# Create a function that can take a list of students and show a pie chart of how students are distributed in ECTS percentage categories (10%, 20%, ...)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

list_of_etcs = {}
for student in students:
    list_of_etcs[student.name] = (student.show_prog()*100)
plt.pie(list_of_etcs.values(),labels= list_of_etcs.keys(), autopct='%.2f')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x2a508880988>,
# ...
#  [Text(0.00699530409172529, 1.0999777569208682, 'nils'),
#   Text(-0.9537915836537988, -0.5479795753047542, 'lulu'),
#   Text(0.09083765275636807, -1.0962429114214212, 'anders'),
#   Text(0.9927938175305713, -0.4736670094835347, 'kauline')],
#  [Text(0.003815620413668339, 0.5999878674113825, '49.80'),
#   Text(-0.5202499547202538, -0.2988979501662295, '17.00'),
#   Text(0.049547810594382576, -0.5979506789571387, '19.03'),
#   Text(0.5415239004712207, -0.25836382335465524, '14.17')])

# %% [markdown]
# create a function that can take a list of students and show how many students have taken each course (bar chart)
#
# create a method on student that can return a list of courses

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt



courses = []
courses_name_list = []
student_pr_course = {}
for student in students:
    courses.extend(student.get_all_courses())
    
for course in courses:
    courses_name_list.append(course.name)
course_name=["danish","latin","spanish","python","math","surfing","botanik","dansing","cooking class","java"]

for course in course_name:
    student_pr_course[course] = courses_name_list.count(course)
print(student_pr_course)


plt.bar(student_pr_course.keys(), student_pr_course.values())
# Out:
# {'danish': 5, 'latin': 3, 'spanish': 4, 'python': 1, 'math': 3, 'surfing': 6, 'botanik': 1, 'dansing': 2, 'cooking class': 4, 'java': 0}
# <img src="data:image/png;base64,..." width="874.4">
# <BarContainer object of 10 artists>

# %% [markdown]
# make the figure show males and females in different colors for each course
